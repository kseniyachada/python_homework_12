# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline


from pandas.io.json import json_normalize
from newsapi.newsapi_client import NewsApiClient
import alpaca_trade_api as tradeapi
from datetime import datetime, timedelta
from nltk.corpus import reuters, stopwords

from pandas.io.json import json_normalize
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Ksenija\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

news_api_key = os.getenv("NEWS_API_KEY")
newsapi = NewsApiClient(api_key=news_api_key)

# %%
# Create a newsapi client

def get_headlines(keyword):
    all_headlines = []
    all_dates = []    
    date = datetime.strptime(current_date[:10], "%Y-%m-%d")
    end_date = datetime.strptime(past_date[:10], "%Y-%m-%d")
    print(f"Fetching news about '{keyword}'")
    print("*" * 30)
    while date > end_date:
        print(f"retrieving news from: {date}")
        articles = newsapi.get_everything(
            q=keyword,
            from_param=str(date)[:10],
            to=str(date)[:10],
            language="en",
            sort_by="relevancy",
            page=1,
        )
        headlines = []
        for i in range(0, len(articles["articles"])):
            headlines.append(articles["articles"][i]["title"])
        all_headlines.append(headlines)
        all_dates.append(date)
        date = date - timedelta(days=1)
    return all_headlines, all_dates

# %%
# Fetch the Bitcoin news articles
current_date = pd.Timestamp(datetime.now(), tz="America/New_York").isoformat()
past_date = pd.Timestamp(datetime.now()- timedelta(30), tz="America/New_York").isoformat()

btc_headlines = newsapi.get_everything(
    q="Bitcoin",
    language="en",
    
)
# Print total articles
print(f"Total articles about Bitcoin: {btc_headlines['totalResults']}")

# Show sample article
btc_headlines["articles"][0]
# Out:
# Total articles about Bitcoin: 7526
# {'source': {'id': 'the-verge', 'name': 'The Verge'},
#  'author': 'Elizabeth Lopatto',
#  'title': 'If you’re a Russian YouTuber, how do you get paid now?',
#  'description': 'Russian creators are shut off from the global financial system. Some of them are turning to cryptocurrency.',
#  'url': 'https://www.theverge.com/2022/3/17/22982122/russia-youtube-crypto-creators-pay-ruble',
#  'urlToImage': 'https://cdn.vox-cdn.com/thumbor/MG_NhB7wSIBIl3S_LG-y-r7iPmg=/0x215:3000x1786/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/9442221/cryptocurrency_0004__00000_.jpg',
#  'publishedAt': '2022-03-17T13:33:43Z',
#  'content': 'When Russia invaded Ukraine, Niki Proshin was already a year into making a living as a vlogger — he had a YouTube channel, a TikTok channel, and an Instagram. He also ran an online Russian club for a… [+5883 chars]'}

# %%
# Fetch the Ethereum news articles
eth_headlines = newsapi.get_everything(
    q="Ethereum",
    language="en",
    
)
# Print total articles
print(f"Total articles about Ethereum: {eth_headlines['totalResults']}")

# Show sample article
eth_headlines["articles"][0]
# Out:
# Total articles about Ethereum: 3682
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Shanti Escalante-De Mattei',
#  'title': 'Web3 Threatens to Segregate Our Online Lives',
#  'description': 'Governance tokens seem like a tantalizing solution to content moderation struggles. They only give the appearance of democracy.',
#  'url': 'https://www.wired.com/story/web3-governance-tokens-cryptocurrency-content-moderation/',
#  'urlToImage': 'https://media.wired.com/photos/621d66c7ea3b8f283853aa29/191:100/w_1280,c_limit/Web3-Threatens-to-Segregate-Our-Online-Lives.jpg',
#  'publishedAt': '2022-03-01T14:00:00Z',
#  'content': 'In February, shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at Ethereum Name Service (ENS), a web3 business, had written the following in May 201… [+3096 chars]'}

# %%
# Create the Bitcoin sentiment scores DataFrame

btc_sentiments = []

for article in btc_headlines["articles"]:
    try:
        text = article["content"].lower()
        title = article["title"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "Text": text,
            "Date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Title Bitcoin": title,
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(btc_sentiments)

# Reorder DataFrame columns
cols = ["Date","Text", "Compound", "Positive", "Negative", "Neutral"]
bitcoin_df = bitcoin_df[cols]
# bitcoin_df.sort_values(by='Negative',ascending=False,inplace=True)
bitcoin_df.tail()
# Out:
#           Date                                               Text  Compound  \
# 15  2022-03-01  the ukrainian government asking for donations ...    0.5574
# 16  2022-03-01  bitcoin rallied to a two-week high on tuesday ...   -0.4588
# 17  2022-03-16  motherboard found old footage from one of the ...    0.0000
# 18  2022-03-02  sec officials do not know the whereabouts of s...   -0.2023
# 19  2022-03-10  one of the biggest criticisms of cryptocurrenc...   -0.2500
#
#     Positive  Negative  Neutral
# 15     0.104     0.000    0.896
# 16     0.069     0.141    0.789
# 17     0.000     0.000    1.000
# 18     0.000     0.053    0.947
# 19     0.065     0.127    0.807

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        text = article["content"]
        
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "Text": text,
            "Date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "Title Ethereum": title,
        
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["Date","Text", "Compound", "Positive", "Negative", "Neutral"]
ethereum_df = ethereum_df[cols]

ethereum_df.tail()
# Out:
#           Date                                               Text  Compound  \
# 15  2022-03-10  (Kitco News) The escalating Russia-Ukraine cri...   -0.5267
# 16  2022-03-10  During the days leading up to the March 11 pur...    0.5106
# 17  2022-03-10  The travel services industry and fast-food cha...    0.4588
# 18  2022-03-10  Personal Finance Insider writes about products...    0.5346
# 19  2022-03-10  A Ukrainian nonprofit has raised bitcoin worth...    0.4939
#
#     Positive  Negative  Neutral
# 15     0.047     0.115    0.838
# 16     0.088     0.000    0.912
# 17     0.091     0.000    0.909
# 18     0.158     0.000    0.842
# 19     0.199     0.083    0.718

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.031460   0.058600   0.045950   0.895350
# std     0.419277   0.053685   0.063433   0.076488
# min    -0.771300   0.000000   0.000000   0.739000
# 25%    -0.214225   0.000000   0.000000   0.843750
# 50%     0.000000   0.060000   0.000000   0.891500
# 75%     0.430825   0.092750   0.073000   0.952500
# max     0.636900   0.171000   0.187000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.214680   0.081850   0.026350   0.891750
# std     0.406766   0.086321   0.039525   0.100824
# min    -0.526700   0.000000   0.000000   0.692000
# 25%     0.000000   0.000000   0.000000   0.841000
# 50%     0.200950   0.068500   0.000000   0.910500
# 75%     0.526700   0.141500   0.052250   1.000000
# max     0.834000   0.249000   0.115000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum with a 0.0818 score
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum with a 0.834 score
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum with a 0.249 score

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text.""" 
    # Remove the punctuation from text
    # Create a tokenized list of the words
    # Lemmatize words into root words
    # Convert the words to lowercase
    # Remove the stop words
    sw= set(stopwords.words('english'))
    sw_addon = {'damn','chars','much','ha'}
    regex= re.compile("[^a-zA-Z ]")
    
    re_clean = regex.sub('', str(text))
    words= word_tokenize(re_clean)
    lem=[lemmatizer.lemmatize(word) for word in words]
    tokens= [word.lower() for word in lem if word.lower() not in sw.union(sw_addon) ]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df["tokens"] = bitcoin_df.Text.apply(tokenizer)
bitcoin_df.head()
# Out:
#          Date                                               Text  Compound  \
# 0  2022-03-17  when russia invaded ukraine, niki proshin was ...    0.0000
# 1  2022-03-12  "bitcoin was seen by many of its libertarian-l...   -0.7713
# 2  2022-03-22  march 22 (reuters) - bitcoin just isn't anonym...    0.6369
# 3  2022-02-22  feb 22 (reuters) - bitcoin miners are feeling ...   -0.1779
# 4  2022-03-01  march 1 (reuters) - bitcoin has leapt since ru...    0.0000
#
#    Positive  Negative  Neutral  \
# 0     0.000     0.000    1.000
# 1     0.000     0.169    0.831
# 2     0.171     0.000    0.829
# 3     0.046     0.067    0.887
# 4     0.000     0.000    1.000
#
#                                               tokens
# 0  [russia, invaded, ukraine, niki, proshin, wa, ...
# 1  [bitcoin, wa, seen, many, libertarianleaning, ...
# 2  [march, reuters, bitcoin, isnt, anonymous, eno...
# 3  [feb, reuters, bitcoin, miner, feeling, heat, ...
# 4  [march, reuters, bitcoin, leapt, since, russia...

# %%
# Create a new tokens column for Ethereum
ethereum_df["tokens"] = ethereum_df.Text.apply(tokenizer)
ethereum_df.head()
# Out:
#          Date                                               Text  Compound  \
# 0  2022-03-10  In February, shit hit the fan in the usual way...   -0.3182
# 1  2022-03-10  Coinbase reported that the share of trading vo...    0.6705
# 2  2022-03-10  Illustration by James Bareham / The Verge\r\n\...   -0.4588
# 3  2022-03-10  His name is Vitalik Buterin and after dedicati...    0.0000
# 4  2022-03-10  It seems that in 2022, you cant escape from th...   -0.1326
#
#    Positive  Negative  Neutral  \
# 0     0.059     0.093    0.848
# 1     0.188     0.000    0.812
# 2     0.000     0.083    0.917
# 3     0.000     0.000    1.000
# 4     0.000     0.044    0.956
#
#                                               tokens
# 0  [february, shit, hit, fan, usual, way, old, tw...
# 1  [coinbase, reported, share, trading, volume, e...
# 2  [illustration, james, bareham, verge, million,...
# 3  [name, vitalik, buterin, dedicating, cover, re...
# 4  [seems, cant, escape, metaversefrom, facebook,...

# %%
btc_token = tokenizer(bitcoin_df.Text.str.cat())
btc_token
# Out:
# ['russia',
#  'invaded',
#  'ukraine',
#  'niki',
#  'proshin',
#  'wa',
#  'already',
#  'year',
#  'making',
#  'living',
#  'vlogger',
#  'youtube',
#  'channel',
#  'tiktok',
#  'channel',
#  'instagram',
#  'also',
#  'ran',
#  'online',
#  'russian',
#  'club',
#  'charsbitcoin',
#  'wa',
#  'seen',
#  'many',
#  'libertarianleaning',
#  'fan',
#  'kind',
#  'doomsday',
#  'insurance',
#  'argues',
#  'columnist',
#  'new',
#  'york',
#  'time',
#  'form',
#  'digital',
#  'gold',
#  'would',
#  'source',
#  'stability',
#  'charsmarch',
#  'reuters',
#  'bitcoin',
#  'isnt',
#  'anonymous',
#  'enough',
#  'growing',
#  'cohort',
#  'crypto',
#  'user',
#  'seeking',
#  'greater',
#  'seclusiona',
#  'volatile',
#  'class',
#  'crypto',
#  'known',
#  'privacy',
#  'coin',
#  'created',
#  'p',
#  'charsfeb',
#  'reuters',
#  'bitcoin',
#  'miner',
#  'feeling',
#  'heat',
#  'pain',
#  'rippling',
#  'downstream',
#  'pressure',
#  'pricesthe',
#  'cryptocurrencys',
#  'spectacular',
#  'rally',
#  'drew',
#  'thousand',
#  'entrant',
#  'mining',
#  'charsmarch',
#  'reuters',
#  'bitcoin',
#  'leapt',
#  'since',
#  'russia',
#  'invasion',
#  'ukraine',
#  'bolstered',
#  'people',
#  'country',
#  'looking',
#  'store',
#  'move',
#  'money',
#  'anonymous',
#  'decentralised',
#  'cryptobitcoin',
#  'tradin',
#  'charswhose',
#  'side',
#  'cryptocurrency',
#  'asked',
#  'satoshi',
#  'nakamoto',
#  'pseudonymous',
#  'person',
#  'person',
#  'created',
#  'bitcoin',
#  'platform',
#  'hethey',
#  'likely',
#  'would',
#  'rejected',
#  'question',
#  'charsheres',
#  'happened',
#  'week',
#  'crypto',
#  'worldgettywelcome',
#  'nonfungible',
#  'tidbit',
#  'weekly',
#  'roundup',
#  'news',
#  'crypto',
#  'nfts',
#  'related',
#  'realmsour',
#  'lead',
#  'story',
#  'week',
#  'possibi',
#  'charsgettywelcome',
#  'nonfungible',
#  'tidbit',
#  'focus',
#  'week',
#  'russia',
#  'war',
#  'ukrainein',
#  'addition',
#  'uprooting',
#  'life',
#  'ukrainian',
#  'throwing',
#  'international',
#  'order',
#  'chaos',
#  'russian',
#  'charsnurphotogettyas',
#  'russia',
#  'launched',
#  'invasion',
#  'home',
#  'country',
#  'last',
#  'thursday',
#  'ukranian',
#  'photographer',
#  'vitaliy',
#  'raskalov',
#  'found',
#  'world',
#  'away',
#  'mexico',
#  'city',
#  'spoke',
#  'telegr',
#  'charslondon',
#  'march',
#  'reuters',
#  'cryptocurrencies',
#  'close',
#  'headline',
#  'since',
#  'russia',
#  'invaded',
#  'ukraine',
#  'evervolatile',
#  'bitcoin',
#  'demand',
#  'russia',
#  'beyondhere',
#  'chart',
#  'l',
#  'charsmarch',
#  'reuters',
#  'bitcoin',
#  'love',
#  'flirting',
#  'mainstream',
#  'u',
#  'president',
#  'say',
#  'want',
#  'get',
#  'serious',
#  'may',
#  'getting',
#  'cold',
#  'crypto',
#  'feetwhen',
#  'joe',
#  'biden',
#  'ordered',
#  'official',
#  'charskennerdell',
#  'pa',
#  'march',
#  'reuters',
#  'vast',
#  'amount',
#  'electricity',
#  'needed',
#  'mine',
#  'bitcoin',
#  'ignited',
#  'debate',
#  'whether',
#  'energy',
#  'behind',
#  'operation',
#  'worth',
#  'potential',
#  'environmental',
#  'co',
#  'charsfeb',
#  'welcome',
#  'home',
#  'realtime',
#  'coverage',
#  'market',
#  'brought',
#  'reuters',
#  'reporter',
#  'share',
#  'thought',
#  'u',
#  'marketsresearchthomsonreuterscombitcoin',
#  'exactly',
#  'charsullisummarylililaw',
#  'firmslilirelated',
#  'documentsliulthe',
#  'company',
#  'law',
#  'firm',
#  'name',
#  'shown',
#  'generated',
#  'automatically',
#  'based',
#  'text',
#  'article',
#  'improving',
#  'charssan',
#  'salvador',
#  'march',
#  'reuters',
#  'el',
#  'salvador',
#  'looking',
#  'right',
#  'timing',
#  'launch',
#  'bitcoinbacked',
#  'bond',
#  'could',
#  'happen',
#  'march',
#  'central',
#  'american',
#  'nation',
#  'finance',
#  'min',
#  'charsthe',
#  'ukrainian',
#  'government',
#  'asking',
#  'donation',
#  'bitcoin',
#  'show',
#  'utility',
#  'cryptocurrency',
#  'positive',
#  'sign',
#  'market',
#  'veteran',
#  'strategist',
#  'tom',
#  'lee',
#  'saidukraine',
#  'government',
#  'accoun',
#  'charsbitcoin',
#  'rallied',
#  'twoweek',
#  'high',
#  'tuesday',
#  'spite',
#  'turmoil',
#  'broader',
#  'market',
#  'thanks',
#  'surge',
#  'buying',
#  'russian',
#  'ukrainian',
#  'may',
#  'seeking',
#  'refuge',
#  'cryptocurrencies',
#  'charsmotherboard',
#  'found',
#  'old',
#  'footage',
#  'one',
#  'first',
#  'major',
#  'bitcoin',
#  'conference',
#  'bitcoin',
#  'san',
#  'jose',
#  'oldthats',
#  'year',
#  'even',
#  'full',
#  'bubblebust',
#  'cyclei',
#  'remember',
#  'bitcoin',
#  'wh',
#  'charssec',
#  'official',
#  'know',
#  'whereabouts',
#  'satish',
#  'kumbhani',
#  'founder',
#  'crypto',
#  'trading',
#  'platform',
#  'bitconnect',
#  'wa',
#  'charged',
#  'last',
#  'week',
#  'defrauding',
#  'investor',
#  'billion',
#  'ponzi',
#  'schem',
#  'charsone',
#  'biggest',
#  'criticism',
#  'cryptocurrency',
#  'large',
#  'particularly',
#  'everpopular',
#  'bitcoin',
#  'market',
#  'regulation',
#  'creates',
#  'extremely',
#  'volatile',
#  'marketting',
#  'shenbloomberg',
#  'char']

# %%
eth_token = tokenizer(ethereum_df.Text.str.cat())
eth_token
# Out:
# ['february',
#  'shit',
#  'hit',
#  'fan',
#  'usual',
#  'way',
#  'old',
#  'tweet',
#  'resurfaced',
#  'brantly',
#  'millegan',
#  'director',
#  'operation',
#  'ethereum',
#  'name',
#  'service',
#  'ens',
#  'web',
#  'business',
#  'written',
#  'following',
#  'may',
#  'charscoinbase',
#  'reported',
#  'share',
#  'trading',
#  'volume',
#  'ethereum',
#  'altcoins',
#  'increased',
#  'last',
#  'year',
#  'bitcoins',
#  'share',
#  'dropped',
#  'dramaticallybetween',
#  'ethereum',
#  'trading',
#  'volume',
#  'charsillustration',
#  'james',
#  'bareham',
#  'verge',
#  'million',
#  'donated',
#  'far',
#  'million',
#  'cryptocurrency',
#  'donated',
#  'ukrainian',
#  'group',
#  'since',
#  'russia',
#  'attacked',
#  'c',
#  'charshis',
#  'name',
#  'vitalik',
#  'buterin',
#  'dedicating',
#  'cover',
#  'recent',
#  'edition',
#  'time',
#  'named',
#  'king',
#  'cryptocurrencies',
#  'bloomberg',
#  'getty',
#  'images',
#  'yearold',
#  'russian',
#  'charsit',
#  'seems',
#  'cant',
#  'escape',
#  'metaversefrom',
#  'facebook',
#  'microsoft',
#  'seemingly',
#  'every',
#  'centralized',
#  'tech',
#  'firm',
#  'clambering',
#  'bandwagon',
#  'emerging',
#  'virtual',
#  'reality',
#  'puris',
#  'charsif',
#  'sound',
#  'good',
#  'true',
#  'youre',
#  'wrong',
#  'yield',
#  'farming',
#  'riskier',
#  'staking',
#  'token',
#  'offering',
#  'high',
#  'interest',
#  'rate',
#  'fee',
#  'yield',
#  'also',
#  'one',
#  'likely',
#  'take',
#  'charsthe',
#  'cryptocurrency',
#  'boom',
#  'past',
#  'year',
#  'helped',
#  'propel',
#  'newer',
#  'market',
#  'record',
#  'height',
#  'digital',
#  'collectible',
#  'known',
#  'nftsin',
#  'fact',
#  'total',
#  'nft',
#  'sale',
#  'volume',
#  'hit',
#  'billion',
#  'past',
#  'charsa',
#  'version',
#  'article',
#  'wa',
#  'published',
#  'times',
#  'newsletter',
#  'metaverse',
#  'subscribe',
#  'weekly',
#  'guide',
#  'future',
#  'internet',
#  'find',
#  'past',
#  'issue',
#  'newsletter',
#  'herelast',
#  'wee',
#  'charsjoe',
#  'biden',
#  'dipping',
#  'toe',
#  'crypto',
#  'wednesday',
#  'president',
#  'signed',
#  'firstofitskind',
#  'executive',
#  'order',
#  'outlining',
#  'path',
#  'regulation',
#  'cryptocurrencies',
#  'encouraging',
#  'federal',
#  'agency',
#  'charsa',
#  'version',
#  'article',
#  'wa',
#  'published',
#  'times',
#  'newsletter',
#  'metaverse',
#  'subscribe',
#  'weekly',
#  'guide',
#  'future',
#  'internet',
#  'find',
#  'past',
#  'issue',
#  'newsletter',
#  'hereits',
#  'bee',
#  'charsthe',
#  'cryptocurrency',
#  'boom',
#  'past',
#  'year',
#  'helped',
#  'propel',
#  'newer',
#  'market',
#  'record',
#  'height',
#  'digital',
#  'collectible',
#  'known',
#  'nftsin',
#  'fact',
#  'total',
#  'nft',
#  'sale',
#  'volume',
#  'hit',
#  'billion',
#  'past',
#  'charsthe',
#  'cryptocurrency',
#  'boom',
#  'past',
#  'year',
#  'helped',
#  'propel',
#  'newer',
#  'market',
#  'record',
#  'height',
#  'digital',
#  'collectible',
#  'known',
#  'nftsin',
#  'fact',
#  'total',
#  'nft',
#  'sale',
#  'volume',
#  'hit',
#  'billion',
#  'past',
#  'charsnew',
#  'york',
#  'march',
#  'reuters',
#  'cryptocurrency',
#  'investment',
#  'product',
#  'fund',
#  'showed',
#  'net',
#  'outflow',
#  'second',
#  'straight',
#  'week',
#  'report',
#  'digital',
#  'asset',
#  'manager',
#  'coinshares',
#  'showed',
#  'monday',
#  'persist',
#  'charsif',
#  'blockchain',
#  'technology',
#  'reach',
#  'true',
#  'mass',
#  'adoption',
#  'become',
#  'cheaper',
#  'efficient',
#  'low',
#  'transaction',
#  'throughput',
#  'popular',
#  'blockchains',
#  'notably',
#  'ethereum',
#  'charsthe',
#  'newsblockchain',
#  'specialistconsensysscooped',
#  'millionin',
#  'series',
#  'round',
#  'value',
#  'usbased',
#  'firm',
#  'billion',
#  'per',
#  'press',
#  'release',
#  'valuation',
#  'doubled',
#  'since',
#  'charskitco',
#  'news',
#  'escalating',
#  'russiaukraine',
#  'crisis',
#  'new',
#  'sanction',
#  'surging',
#  'oil',
#  'price',
#  'investor',
#  'fleeing',
#  'riskon',
#  'asset',
#  'crypto',
#  'space',
#  'getting',
#  'safehaven',
#  'appeal',
#  'back',
#  'peop',
#  'charsduring',
#  'day',
#  'leading',
#  'march',
#  'purchase',
#  'yuga',
#  'labs',
#  'intellectual',
#  'property',
#  'meebits',
#  'collection',
#  'larva',
#  'labs',
#  'dozen',
#  'address',
#  'ethereum',
#  'blockchain',
#  'purchas',
#  'charsthe',
#  'travel',
#  'service',
#  'industry',
#  'fastfood',
#  'chain',
#  'among',
#  'leading',
#  'widening',
#  'acceptance',
#  'cryptocurrencies',
#  'payment',
#  'good',
#  'service',
#  'research',
#  'released',
#  'tuesday',
#  'showedof',
#  'top',
#  'charspersonal',
#  'finance',
#  'insider',
#  'writes',
#  'product',
#  'strategy',
#  'tip',
#  'help',
#  'make',
#  'smart',
#  'decision',
#  'money',
#  'may',
#  'receive',
#  'small',
#  'commission',
#  'partner',
#  'like',
#  'american',
#  'express',
#  'charsa',
#  'ukrainian',
#  'nonprofit',
#  'raised',
#  'bitcoin',
#  'worth',
#  'million',
#  'support',
#  'country',
#  'army',
#  'since',
#  'russia',
#  'attacked',
#  'according',
#  'blockchain',
#  'analytics',
#  'company',
#  'ellipticcome',
#  'back',
#  'alive',
#  'charita',
#  'char']

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
N=2
ngrams_bitcoin = Counter(ngrams(btc_token, N))
print(dict(ngrams_bitcoin))
# Out:
# {('russia', 'invaded'): 2, ('invaded', 'ukraine'): 2, ('ukraine', 'niki'): 1, ('niki', 'proshin'): 1, ('proshin', 'wa'): 1, ('wa', 'already'): 1, ('already', 'year'): 1, ('year', 'making'): 1, ('making', 'living'): 1, ('living', 'vlogger'): 1, ('vlogger', 'youtube'): 1, ('youtube', 'channel'): 1, ('channel', 'tiktok'): 1, ('tiktok', 'channel'): 1, ('channel', 'instagram'): 1, ('instagram', 'also'): 1, ('also', 'ran'): 1
# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_common= token_count(btc_token, 10)
btc_common
# Out:
# [('bitcoin', 12),
#  ('reuters', 8),
#  ('russia', 6),
#  ('crypto', 6),
#  ('week', 4),
#  ('march', 4),
#  ('market', 4),
#  ('ukraine', 3),
#  ('wa', 3),
#  ('russian', 3)]

# %%
# Use token_count to get the top 10 words for Ethereum
eth_common= token_count(eth_token,10)
eth_common
# Out:
# [('past', 8),
#  ('ethereum', 5),
#  ('volume', 5),
#  ('cryptocurrency', 5),
#  ('charsthe', 5),
#  ('hit', 4),
#  ('year', 4),
#  ('digital', 4),
#  ('billion', 4),
#  ('newsletter', 4)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
cloud1 = WordCloud(background_color='grey').generate(bitcoin_df.Text.str.cat())
cloud1
plt.axis("off")
plt.imshow(cloud1)

# %%
# Generate the Ethereum word cloud
cloud2 = WordCloud(background_color='grey').generate(ethereum_df.Text.str.cat())
cloud2
plt.axis("off")
plt.imshow(cloud2)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
all_concat_bitcoin = bitcoin_df.Text.str.cat()
all_concat_bitcoin
# Out:
# 'when russia invaded ukraine, niki proshin was already a year into making a living as a vlogger — he had a youtube channel, a tiktok channel, and an instagram. he also ran an online russian club for a… [+5883 chars]"bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance," argues a columnist in the new york times, "a form of \'digital gold\' that would be a source of stability as … [+3914 chars]march 22 (reuters) - bitcoin just isn\'t anonymous enough for a growing cohort of crypto users who are seeking greater seclusion.\r\na volatile class of crypto known as privacy coins, created with the p… [+4776 chars]feb 22 (reuters) - bitcoin miners are feeling the heat - and the pain\'s rippling downstream to pressure prices.\r\nthe cryptocurrency\'s spectacular rally in 2021 drew thousands of entrants into mining,… [+4196 chars]march 1 (reuters) - bitcoin has leapt since russia\'s invasion of ukraine, bolstered by people in those countries looking to store and move money in anonymous and decentralised crypto.\r\nbitcoin tradin… [+3955 chars]whose side is cryptocurrency on? if you had asked satoshi nakamoto, the pseudonymous person (or persons) who created the bitcoin platform in 2008, he/they likely would have rejected the question. the… [+3643 chars]here\'s what happened this week in the crypto world.\r\ngetty\r\nwelcome to nonfungible tidbits, a weekly roundup of news in crypto, nfts and their related realms.\r\nour lead story this week is the possibi… [+2860 chars]getty\r\nwelcome to nonfungible tidbits. our focus this week: russia\'s war in ukraine.\xa0\r\nin addition to uprooting the lives of ukrainians and throwing the international order into chaos, the russian in… [+3275 chars]nurphoto/getty\r\nas russia launched an invasion into his home country last thursday, ukranian photographer vitaliy raskalov found himself a world away in mexico city. when i spoke with him over telegr… [+7815 chars]london, march 4 (reuters) - cryptocurrencies have been close to the headlines since russia invaded ukraine, with the ever-volatile bitcoin in demand in russia and beyond.\r\nhere are some charts that l… [+3634 chars]march 15 (reuters) - bitcoin loves flirting with the mainstream. but now, as the u.s. president says he wants to get serious, it may be getting cold crypto feet.\r\nwhen joe biden ordered officials to … [+4501 chars]kennerdell, pa., march 21 (reuters) - the vast amounts of electricity needed to mine bitcoin has ignited a debate about whether the energy behind the operation is worth the potential environmental co… [+1781 chars]feb 24 - welcome to the home for real-time coverage of markets brought to you by reuters reporters. you can share your thoughts with us at markets.research@thomsonreuters.com\r\nbitcoin, not exactly a … [+6882 chars]<ul><li>\r\nsummary</li><li>\r\nlaw firms</li><li>\r\nrelated documents</li></ul>\r\nthe company and law firm names shown above are generated automatically based on the text of the article. we are improving … [+2414 chars]san salvador, march 11 (reuters) - el salvador is looking for the right timing to launch its bitcoin-backed bond, which could happen between march 15 and 20, the central american nation\'s finance min… [+533 chars]the ukrainian government asking for donations in bitcoin shows the utility of the cryptocurrency and is a positive sign for the market, veteran strategist tom lee has said.\r\nukraine government accoun… [+1750 chars]bitcoin rallied to a two-week high on tuesday in spite of the turmoil on the broader markets, thanks to a surge in buying by russians and ukrainians who may be seeking refuge in cryptocurrencies as t… [+2894 chars]motherboard found old footage from one of the first major bitcoin conferences: bitcoin 2013 in san jose.\r\n2013 is old.\r\nthat\'s only 9 years - not even a full bubble-bust cycle.\r\ni remember bitcoin wh… [+424 chars]sec officials do not know the whereabouts of satish kumbhani, the founder of crypto trading plat ...

# %%
# Run the NER processor on all of the text
bitcoin_doc = nlp(all_concat_bitcoin)
bitcoin_doc
# Add a title to the document
bitcoin_doc.user_data["Title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_doc, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">when
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  invaded ukraine, niki proshin was already
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into making a living as a vlogger — he had a youtube channel, a tiktok channel, and an instagram. he also ran an online
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  club for a… [+5883 chars]&quot;bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance,&quot; argues a columnist in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the new york times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , &quot;a form of 'digital gold' that would be a source of stability as … [+3914 chars]march
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>a volatile class of crypto known as privacy coins, created with the p… [+4776 chars]feb
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>the cryptocurrency's spectacular rally in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  drew
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of entrants into mining,… [+4196 chars]march 1 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - bitcoin has leapt since
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>bitcoin
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tradin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# … [+3955 chars]whose side is cryptocurrency on? if you had asked
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     satoshi nakamoto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the pseudonymous person (or persons) who created the bitcoin platform in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he/they likely would have rejected the question. the… [+3643 chars]here's what happened
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     getty
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# welcome to nonfungible tidbits, a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>our lead story
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>welcome to nonfungible tidbits. our focus
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>in addition to uprooting the lives of ukrainians and throwing the international order into chaos, the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  in… [
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +3275
#     <span

# %%
# List all Entities
for i in bitcoin_doc.ents:
    print(i.text, i.label_)
# Out:
# russia GPE
# a year DATE
# russian NORP
# the new york times ORG
# 22 CARDINAL
# reuters ORG
# 22 CARDINAL
# reuters ORG
# 2021 DATE
# thousands CARDINAL
# reuters ORG
# russia GPE
# tradin GPE
# satoshi nakamoto PERSON
# 2008 DATE
# this week DATE
# getty
#  ORG
# weekly DATE
# this week DATE
# this week DATE
# russia GPE
# russian NORP
# +3275 ORG
# russia GPE
# last thursday DATE
# mexico city GPE
# march 4 DATE
# reuters ORG
# russia GPE
# russia GPE
# 15 CARDINAL
# reuters ORG
# u.s. GPE
# joe biden PERSON
# pa. GPE
# march 21 DATE
# reuters ORG
# 24 CARDINAL
# reuters ORG
# +6882 chars]<ul><li>
#  ORG
# summary</li><li ORG
# firms</li><li ORG
# documents</li></ul GPE
# march 11 DATE
# reuters ORG
# el salvador GPE
# between march 15 and 20 DATE
# central american NORP
# tom lee PERSON
# two-week DATE
# tuesday DATE
# russians NORP
# one CARDINAL
# first ORDINAL
# 2013 DATE
# san jose GPE
# 2013 DATE
# only 9 years DATE
# last week DATE
# $2.4 billion MONEY
# ting shen/bloomberg PERSON

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
all_concat_ethereum = ethereum_df.Text.str.cat()
all_concat_ethereum
# Out:
# "In February, shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at Ethereum Name Service (ENS), a web3 business, had written the following in May 201… [+3096 chars]Coinbase reported that the share of trading volume for ethereum and other altcoins increased last year, while bitcoin's share dropped dramatically.\xa0\r\nBetween 2020 and 2021, ethereum trading volume in… [+1187 chars]Illustration by James Bareham / The Verge\r\n\n \n\n\n More than $15 million has been donated so far More than $15 million in cryptocurrency has been donated to Ukrainian groups since Russia attacked the c… [+7442 chars]His name is Vitalik Buterin and after dedicating the cover of its most recent edition to him, TIME has named him the King of Cryptocurrencies .\r\nBloomberg | Getty Images\r\n The 28-year-old Russian is … [+2627 chars]It seems that in 2022, you cant escape from the metaverse.\xa0From Facebook to Microsoft, seemingly every centralized tech firm is clambering on the bandwagon of this emerging virtual reality. For puris… [+5412 chars]If it sounds too good to be true, youre not wrong. Yield farming is riskier than staking. The tokens that are offering such high interest rates and fee yields are also the ones most likely to take a … [+2371 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nIn fact, total NFT sales volume hit $23 billion over the past… [+2680 chars]A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet. You can find past issues of the newsletter here.\r\nLast wee… [+7988 chars]Joe Biden is dipping his toes into crypto. On Wednesday, the president signed a first-of-its-kind executive order outlining a path to regulation of cryptocurrencies and encouraging federal agencies t… [+2590 chars]A version of this article was published in TIME’s newsletter Into the Metaverse. Subscribe for a weekly guide to the future of the Internet. You can find past issues of the newsletter here.\r\nIt’s bee… [+15336 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nIn fact, total NFT sales volume hit $23 billion over the past… [+2603 chars]The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nIn fact, total NFT sales volume hit $23 billion over the past… [+2633 chars]NEW YORK, March 21 (Reuters) - Cryptocurrency investment products and funds showed net outflows for a second straight week, a report from digital asset manager CoinShares showed on Monday, on persist… [+2322 chars]If blockchain technology is to reach true mass adoption, it will have to become cheaper and more efficient. Low transaction throughput on some of the most popular blockchains, most notably Ethereum, … [+1852 chars]The news:\xa0Blockchain specialist\xa0ConsenSys\xa0scooped $450 million\xa0in a Series D round that values the US-based firm at over $7 billion, per a press release. Its valuation has more than doubled since its… [+2949 chars](Kitco News) The escalating Russia-Ukraine crisis, new sanctions, and surging oil prices have investors fleeing risk-on assets. And the crypto space is getting its safe-haven appeal back as more peop… [+3790 chars]During the days leading up to the March 11 purchase by Yuga Labs of the intellectual property of the Meebits collection from Larva Labs, more than a dozen addresses on the Ethereum blockchain purchas… [+556 chars]The travel services industry and fast-food chains are among those leading the widening acceptance of cryptocurrencies as payment for goods and services, research released Tuesday showed.\xa0\r\nOf the top… [+2321 chars]Personal Finance Insider writes about products, strategies, and tips to help you make smart d ...

# %%
# Run the NER processor on all of the text
ethereum_doc = nlp(all_concat_ethereum)
ethereum_doc

# Add a title to the document
ethereum_doc.user_data["Title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(ethereum_doc, style = 'ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Name Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ENS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), a web3 business, had written the following in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 201
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# … [+3096 chars]Coinbase reported that the share of trading volume for ethereum and other altcoins increased
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Between 2020 and 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , ethereum trading volume in… [+1187 chars]Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Bareham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br> </br></br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  has been donated so far
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     More than $15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in cryptocurrency has been donated to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukrainian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  groups since
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  attacked the c… [+7442 chars]His name is
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and after dedicating the cover of its most recent edition to him,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TIME
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  |
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br> The
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  is … [+2627 chars]It seems that in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , you cant escape from the metaverse. From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , seemingly every centralized tech firm is clambering on the bandwagon of this emerging virtual reality. For puris… [+5412 chars]If it sounds too good to be true, youre not wrong. Yield farming is riskier than staking. The tokens that are offering such high interest rates and fee yields are also the ones most likely to take a … [+2371 chars]The cryptocurrency boom over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past few years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>In fact, total
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sales volume hit
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius:

# %%
# List all Entities
for i in ethereum_doc.ents:
    print(i.text, i.label_)
# Out:
# February DATE
# Ethereum Name Service ORG
# ENS ORG
# May 201 DATE
# last year DATE
# Between 2020 and 2021 DATE
# James Bareham PERSON
# More than $15 million MONEY
# More than $15 million MONEY
# Ukrainian GPE
# Russia GPE
# Vitalik Buterin PERSON
# TIME ORG
# Bloomberg GPE
# Getty Images PERSON
# 28-year-old DATE
# Russian NORP
# 2022 DATE
# Facebook ORG
# Microsoft ORG
# the past few years DATE
# NFT ORG
# $23 billion MONEY
# TIME ORG
# weekly DATE
# Biden PERSON
# Wednesday DATE
# first ORDINAL
# TIME ORG
# weekly DATE
# the past few years DATE
# NFT ORG
# $23 billion MONEY
# the past few years DATE
# NFT ORG
# $23 billion MONEY
# chars]NEW YORK GPE
# March 21 DATE
# Reuters ORG
# a second straight week DATE
# CoinShares ORG
# Monday DATE
# chars]If PERSON
# Ethereum ORG
# $450 million MONEY
# Series EVENT
# US GPE
# over $7 billion MONEY
# Russia GPE
# Ukraine GPE
# days DATE
# March 11 DATE
# Yuga Labs PERSON
# Meebits NORP
# Larva Labs PERSON
# more than a dozen CARDINAL
# Ethereum ORG
# Tuesday DATE
# Finance Insider PERSON
# American Express ORG
# Ukrainian NORP
# more than $4 million MONEY
# Russia GPE
# Elliptic LOC

# %% [markdown]
# ---
